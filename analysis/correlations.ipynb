# %%
# Import the required libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings
from IPython.display import HTML
import seaborn as sns
import scipy.stats as stats
#import plotly.graph_objects as go
#import plotly.express as px

# Set any preferences you want for the notebook
warnings.filterwarnings('ignore')

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# Set the home directory to the main repository page

os.chdir('..')
os.listdir()
# Out:
# ['.DS_Store', 'analysis', 'docs', 'README.md', '.git', 'data']

# %%
# Read in the dataset

df = pd.read_csv('data/data.csv')

# %%
# Create a column called 'company' which identifies where a company belongs to

df['company'] = 1

company_number = 1
for i in range(1, len(df['company'])):
    if df['Stock return'][i] == df['Stock return'][i-1]:
        df['company'][i] = company_number
    else:
        company_number = company_number + 1
        df['company'][i] = company_number

# %% [markdown]
# ### Employee Level Correlation

# %%
df.corr()
# Out:
#                               Compensation  Log(sales)  Stock return  \
# Compensation                      1.000000    0.162819      0.215032
# Log(sales)                        0.162819    1.000000      0.054288
# Stock return                      0.215032    0.054288      1.000000
# Volatility                       -0.068603   -0.023857      0.044127
# Board size                        0.152201    0.106983      0.043654
# Fraction of female                0.062700    0.035304     -0.109763
# Fraction of independent           0.114229    0.076325      0.025261
# Gender                            0.049193    0.018224     -0.056659
# Age                              -0.062640   -0.011466      0.024939
# Tenure                           -0.058645    0.025234     -0.033032
# Number of other directorship     -0.048328   -0.026219      0.024531
# Retired                          -0.014662    0.025771      0.032892
# company                           0.026114   -0.121688      0.017552
#
#                               Volatility  Board size  Fraction of female  \
# Compensation                   -0.068603    0.152201            0.062700
# Log(sales)                     -0.023857    0.106983            0.035304
# Stock return                    0.044127    0.043654           -0.109763
# Volatility                      1.000000   -0.063345            0.019086
# Board size                     -0.063345    1.000000            0.052117
# Fraction of female              0.019086    0.052117            1.000000
# Fraction of independent         0.074161    0.367382            0.050616
# Gender                          0.009852    0.026903            0.516196
# Age                            -0.035535   -0.001452           -0.042869
# Tenure                          0.011064   -0.022462            0.018210
# Number of other directorship    0.004166   -0.054332           -0.021414
# Retired                        -0.006270    0.017596           -0.001785
# company                        -0.051532   -0.047621           -0.028632
#
#                               Fraction of independent    Gender       Age  \
# Compensation                                 0.114229  0.049193 -0.062640
# Log(sales)                                   0.076325  0.018224 -0.011466
# Stock return                                 0.025261 -0.056659  0.024939
# Volatility                                   0.074161  0.009852 -0.035535
# Board size                                   0.367382  0.026903 -0.001452
# Fraction of female                           0.050616  0.516196 -0.042869
# Fraction of independent                      1.000000  0.026128  0.003162
# Gender                                       0.026128  1.000000 -0.006069
# Age                                          0.003162 -0.006069  1.000000
# Tenure                                      -0.006616 -0.028995  0.018058
# Number of other directorship                -0.041554 -0.009615  0.029775
# Retired                                      0.040557 -0.012263  0.010105
# company                                      0.035325 -0.014780 -0.017206
#
#                                 Tenure  Number of other directorship  \
# Compensation                 -0.058645                     -0.048328
# Log(sales)                    0.025234                     -0.026219
# Stock return                 -0.033032                      0.024531
# Volatility                    0.011064                      0.004166
# Board size                   -0.022462                     -0.054332
# Fraction of female            0.018210                     -0.021414
# Fraction of independent      -0.006616                     -0.041554
# Gender                       -0.028995                     -0.009615
# Age                           0.018058                      0.029775
# Tenure                        1.000000                      0.023896
# Number of other directorship  0.023896                      1.000000
# Retired                       0.011761                      0.008078
# company                      -0.017517                      0.037404
#
#                                Retired   company
# Compensation                 -0.014662  0.026114
# Log(sales)                    0.025771 -0.121688
# Stock return                  0.032892  0.017552
# Volatility                   -0.006270 -0.051532
# Board size                    0.017596 -0.047621
# Fraction of female           -0.001785 -0.028632
# Fraction of independent       0.040557  0.035325
# Gender                       -0.012263 -0.014780
# Age                           0.010105 -0.017206
# Tenure                        0.011761 -0.017517
# Number of other directorship  0.008078  0.037404
# Retired                       1.000000 -0.000809
# company                      -0.000809  1.000000

# %% [markdown]
# ### Company Level Correlation

# %%
df_cmp = df[['company', 'Log(sales)', 'Stock return', 'Volatility', 'Board size', 'Fraction of female', 'Fraction of independent']].drop_duplicates(ignore_index = True)
df_cmp.corr()
# Out:
#                           company  Log(sales)  Stock return  Volatility  \
# company                  1.000000   -0.103231      0.005355   -0.036281
# Log(sales)              -0.103231    1.000000      0.043957   -0.014757
# Stock return             0.005355    0.043957      1.000000    0.038571
# Volatility              -0.036281   -0.014757      0.038571    1.000000
# Board size              -0.018666    0.130304      0.007450   -0.029571
# Fraction of female      -0.004264    0.076692     -0.088846    0.007620
# Fraction of independent  0.015970    0.117107      0.025713    0.067556
#
#                          Board size  Fraction of female  \
# company                   -0.018666           -0.004264
# Log(sales)                 0.130304            0.076692
# Stock return               0.007450           -0.088846
# Volatility                -0.029571            0.007620
# Board size                 1.000000            0.131014
# Fraction of female         0.131014            1.000000
# Fraction of independent    0.419892            0.091038
#
#                          Fraction of independent
# company                                 0.015970
# Log(sales)                              0.117107
# Stock return                            0.025713
# Volatility                              0.067556
# Board size                              0.419892
# Fraction of female                      0.091038
# Fraction of independent                 1.000000
